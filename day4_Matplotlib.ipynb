# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(0,10)
y = x**2 

plt.plot(x,y) #plot() draws a simple line
plt.show()

# %%
X = np.random.randn(100)
Y = np.random.randn(100)

df1 = pd.DataFrame(X,Y) 
print(df1)

plt.scatter(X,Y) #scatter() draws a scatterplot 
plt.show()
# Out:
#                   0
# -1.475667  1.989335
#  1.054252 -0.652662
#  0.687664  0.908137
# -0.100972  0.534831
# -0.592737  0.418991
# ...             ...
#  0.461320 -1.772019
# -0.495232 -1.869725
# -0.841990 -1.948513
#  0.779594 -1.254690
# -1.648366 -0.432242
#
# [100 rows x 1 columns]

# %%
students = ["A", "B", "C", "D", "E", "F", "G", "H"]
score= [90, 85, 88, 86, 78, 92, 85, 66]

plt.bar(students, score) #bar() draws a bar chart
plt.show()

# %%
students = ["A", "B", "C", "D", "E", "F", "G", "H"]
score= [90, 85, 88, 86, 78, 92, 85, 66]

plt.plot(students,score, color="red", linewidth=2, linestyle="--", marker="o")
plt.title("Final exam scores of students")
plt.xlabel("Participating Students")
plt.ylabel("Correspondent Scores")
plt.show()

# %%
#process to draw multiple graphs
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(x, y)
axs[0].set_title("Square")

axs[1].plot(x, x*3)
axs[1].set_title("Linear")

plt.show()

# %%
data = pd.DataFrame({
    "age": np.random.randint(18, 60, size=200)
})

plt.hist(data["age"], color="red",bins=15)
plt.title("Age Distribution")
plt.show()

# %%
from sklearn.datasets import make_blobs
from sklearn.svm import SVC

# Create dataset
X, y = make_blobs(n_samples=200, centers=2, random_state=0)

# Train classifier
clf = SVC(kernel='linear').fit(X, y)

# Plot data
plt.scatter(X[:,0], X[:,1], c=y)

# Plot decision boundary
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)

YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

ax.contour(XX, YY, Z, levels=[0], linewidths=2, colors='black')
plt.show()
